# %% [markdown]
# # Lab 3: Data Visualization and Exploratory Data Analysis (EDA)
#
# **Name:** Amit Bhowmik
# **Department:** Computer Science and Engineering
# **ID:** 232031017
# **University:** Feni University
#
# ### Objectives
# - Histograms
# - Bar charts
# - Scatter plots
# - Box plots
# - Correlation matrix and heatmap
# - Identifying outliers and relationships
# - Analyze relationships between important features

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns


sns.set_theme(style="whitegrid")

# %%
path = "data/student_dropout.csv"
df = pd.read_csv(path)

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (10000, 19)

# %% [markdown]
# ### Histogram

# %%
# Histogram: Age

plt.figure(figsize=(8, 5))

plt.hist(
    df["Age"],
    bins=15,
    edgecolor="black"
)

plt.title("Distribution of Student Age")
plt.xlabel("Age")
plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# ### Explanation
#
# The histogram shows how students are distributed according to age. It helps identify the most common age range and whether unusually high or low ages exist.

# %%
# Histogram: GPA

plt.figure(figsize=(8, 5))

plt.hist(
    df["GPA"],
    bins=20,
    edgecolor="black"
)

plt.title("Distribution of GPA")
plt.xlabel("GPA")
plt.ylabel("Number of Students")

plt.show()

# %%
# Histogram: Study Hours Per Day

plt.figure(figsize=(8, 5))

plt.hist(
    df["Study_Hours_per_Day"],
    bins=15,
    edgecolor="black"
)

plt.title("Distribution of Daily Study Hours")
plt.xlabel("Study Hours per Day")
plt.ylabel("Number of Students")

plt.show()

# %%
# Histogram: Attendance Rate

plt.figure(figsize=(8, 5))

plt.hist(
    df["Attendance_Rate"],
    bins=20,
    edgecolor="black"
)

plt.title("Distribution of Attendance Rate")
plt.xlabel("Attendance Rate (%)")
plt.ylabel("Number of Students")

plt.show()

# %%
# Histogram: Stress Index

plt.figure(figsize=(8, 5))

plt.hist(
    df["Stress_Index"],
    bins=15,
    edgecolor="black"
)

plt.title("Distribution of Student Stress Index")
plt.xlabel("Stress Index")
plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# ### Bar chart

# %%
# Bar chart: Scholarship Distribution

plt.figure(figsize=(7, 5))

ax = sns.countplot(
    data=df,
    x="Scholarship"
)

plt.title("Scholarship Distribution")
plt.xlabel("Scholarship")
plt.ylabel("Number of Students")

for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
# Bar chart: Internet Access

plt.figure(figsize=(7, 5))

ax = sns.countplot(
    data=df,
    x="Internet_Access"
)

plt.title("Internet Access Distribution")
plt.xlabel("Internet Access")
plt.ylabel("Number of Students")

for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
# Bar chart: Part-Time Job

plt.figure(figsize=(7, 5))

ax = sns.countplot(
    data=df,
    x="Part_Time_Job"
)

plt.title("Part-Time Job Distribution")
plt.xlabel("Part-Time Job")
plt.ylabel("Number of Students")

for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %% [markdown]
# ### Scatter plot

# %%
# Scatter plot: Attendance Rate vs GPA

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="Attendance_Rate",
    y="GPA",
    hue="Dropout"
)

plt.title("Attendance Rate vs GPA by Dropout Status")
plt.xlabel("Attendance Rate (%)")
plt.ylabel("GPA")

plt.show()

# %% [markdown]
# ### Interpretation
#
# This visualization helps investigate whether students with lower attendance and lower GPA are more likely to belong to the dropout category.

# %%
# Scatter plot: Study Hours vs GPA

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="Study_Hours_per_Day",
    y="GPA",
    hue="Dropout"
)

plt.title("Study Hours vs GPA by Dropout Status")
plt.xlabel("Study Hours per Day")
plt.ylabel("GPA")

plt.show()

# %%
# Scatter plot: Stress Index vs GPA

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="Stress_Index",
    y="GPA",
    hue="Dropout"
)

plt.title("Stress Index vs GPA by Dropout Status")
plt.xlabel("Stress Index")
plt.ylabel("GPA")

plt.show()

# %%
# Scatter plot: Assignment Delay vs GPA

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="Assignment_Delay_Days",
    y="GPA",
    hue="Dropout"
)

plt.title("Assignment Delay vs GPA by Dropout Status")
plt.xlabel("Assignment Delay (Days)")
plt.ylabel("GPA")

plt.show()

# %% [markdown]
# ### Box plot

# %%
# Box plot: GPA

plt.figure(figsize=(7, 5))

sns.boxplot(
    data=df,
    y="GPA"
)

plt.title("Box Plot of GPA")
plt.ylabel("GPA")

plt.show()

# %%
# Box plot: Attendance Rate

plt.figure(figsize=(7, 5))

sns.boxplot(
    data=df,
    y="Attendance_Rate"
)

plt.title("Box Plot of Attendance Rate")
plt.ylabel("Attendance Rate (%)")

plt.show()

# %%
# Box plot: Stress Index

plt.figure(figsize=(7, 5))

sns.boxplot(
    data=df,
    y="Stress_Index"
)

plt.title("Box Plot of Stress Index")
plt.ylabel("Stress Index")

plt.show()

# %%
# Box plot: GPA by Dropout Status

plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Dropout",
    y="GPA"
)

plt.title("GPA Distribution by Dropout Status")
plt.xlabel("Dropout Status")
plt.ylabel("GPA")

plt.show()

# %%
# Box plot: Attendance Rate by Dropout Status

plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Dropout",
    y="Attendance_Rate"
)

plt.title("Attendance Rate by Dropout Status")
plt.xlabel("Dropout Status")
plt.ylabel("Attendance Rate (%)")

plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
# Select numerical columns

numeric_df = df.select_dtypes(include=np.number).copy()

# Remove Student_ID because it is only an identifier
if "Student_ID" in numeric_df.columns:
    numeric_df = numeric_df.drop(columns=["Student_ID"])

print("Numerical Features:")
print(numeric_df.columns.tolist())
# Out:
# Numerical Features:
# ['Age', 'Family_Income', 'Study_Hours_per_Day', 'Attendance_Rate', 'Assignment_Delay_Days', 'Travel_Time_Minutes', 'Stress_Index', 'GPA', 'Semester_GPA', 'CGPA', 'Dropout']

# %%
# Calculate correlation matrix

correlation_matrix = numeric_df.corr()

correlation_matrix
# Out:
#                             Age  Family_Income  Study_Hours_per_Day  \
# Age                    1.000000       0.008366             0.001722
# Family_Income          0.008366       1.000000             0.003867
# Study_Hours_per_Day    0.001722       0.003867             1.000000
# Attendance_Rate        0.011307      -0.008219            -0.015778
# Assignment_Delay_Days  0.012405       0.007179             0.000259
# Travel_Time_Minutes   -0.014714       0.018514             0.011599
# Stress_Index          -0.023865      -0.021417             0.008643
# GPA                   -0.010184      -0.000808             0.214687
# Semester_GPA          -0.009947       0.002917             0.207719
# CGPA                  -0.010478       0.001882             0.208077
# Dropout                0.007585      -0.011123            -0.089376
#
#                        Attendance_Rate  Assignment_Delay_Days  \
# Age                           0.011307               0.012405
# ...

# %%
# Correlation Heatmap

plt.figure(figsize=(12, 9))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numerical Features")

plt.show()

# %% [markdown]
# ### Interpretation
#
# **The correlation coefficient ranges from -1 to +1:**
#
# - +1 → strong positive relationship
# - -1 → strong negative relationship
# - 0 → little or no linear relationship
#
# For example, GPA, Semester GPA, and CGPA may show strong relationships because they represent related academic performance measures.

# %% [markdown]
# ### Outlier Detection
# We will use the Interquartile Range (IQR) method.

# %%
# Detect GPA outliers using IQR

Q1 = df["GPA"].quantile(0.25)
Q3 = df["GPA"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[
    (df["GPA"] < lower_bound) |
    (df["GPA"] > upper_bound)
]

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
print("Number of GPA Outliers:", len(outliers))
# Out:
# Q1: 1.55
# Q3: 3.12
# IQR: 1.57
# Lower Bound: -0.8049999999999999
# Upper Bound: 5.475
# Number of GPA Outliers: 0

# %%
# Detect outliers in important numerical features

features = [
    "Age",
    "Study_Hours_per_Day",
    "Attendance_Rate",
    "Assignment_Delay_Days",
    "Travel_Time_Minutes",
    "Stress_Index",
    "GPA",
    "Semester_GPA",
    "CGPA"
]

print("Outlier Analysis")
print("=" * 50)

for column in features:

    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outlier_count = (
        (df[column] < lower_bound) |
        (df[column] > upper_bound)
    ).sum()

    print(f"{column}: {outlier_count} outliers")
# Out:
# Outlier Analysis
# ...
# Age: 33 outliers
# Study_Hours_per_Day: 86 outliers
# Attendance_Rate: 57 outliers
# Assignment_Delay_Days: 25 outliers
# Travel_Time_Minutes: 25 outliers
# Stress_Index: 0 outliers
# GPA: 0 outliers
# Semester_GPA: 0 outliers
# CGPA: 0 outliers

# %% [markdown]
# ### Analyze Relationships

# %%
# Find strongest relationships between numerical features

corr = numeric_df.corr()

correlation_pairs = corr.unstack()

# Remove self-correlations
correlation_pairs = correlation_pairs[
    correlation_pairs.index.get_level_values(0)
    != correlation_pairs.index.get_level_values(1)
]

# Sort by absolute correlation
correlation_pairs = correlation_pairs.abs().sort_values(
    ascending=False
)

print("Top 10 Strongest Relationships:")
print(correlation_pairs.head(10))
# Out:
# Top 10 Strongest Relationships:
# Semester_GPA  CGPA            0.999214
# CGPA          Semester_GPA    0.999214
# Semester_GPA  GPA             0.964275
# GPA           Semester_GPA    0.964275
# CGPA          GPA             0.963432
# GPA           CGPA            0.963432
#               Dropout         0.460352
# Dropout       GPA             0.460352
#               Semester_GPA    0.445396
# Semester_GPA  Dropout         0.445396
# dtype: float64

# %% [markdown]
# ### Dropout Analysis
# This section is especially useful because your project's main goal is student dropout prediction.

# %%
# Display dropout counts

print("Dropout Distribution:")
print(df["Dropout"].value_counts())
# Out:
# Dropout Distribution:
# Dropout
# 0    7646
# 1    2354
# Name: count, dtype: int64

# %%
# Calculate dropout percentages

dropout_percentage = (
    df["Dropout"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

print("Dropout Percentage:")
print(dropout_percentage)
# Out:
# Dropout Percentage:
# Dropout
# 0    76.46
# 1    23.54
# Name: proportion, dtype: float64

# %%
# Average GPA according to dropout status

average_gpa = df.groupby("Dropout")["GPA"].mean()

print("Average GPA by Dropout Status:")
print(average_gpa)
# Out:
# Average GPA by Dropout Status:
# Dropout
# 0    2.579623
# 1    1.427613
# Name: GPA, dtype: float64

# %%
# Average Attendance according to dropout status

average_attendance = df.groupby("Dropout")["Attendance_Rate"].mean()

print("Average Attendance by Dropout Status:")
print(average_attendance)
# Out:
# Average Attendance by Dropout Status:
# Dropout
# 0    82.482775
# 1    79.313934
# Name: Attendance_Rate, dtype: float64

# %%
# Average Study Hours according to dropout status

average_study_hours = df.groupby("Dropout")["Study_Hours_per_Day"].mean()

print("Average Study Hours by Dropout Status:")
print(average_study_hours)
# Out:
# Average Study Hours by Dropout Status:
# Dropout
# 0    4.07892
# 1    3.80622
# Name: Study_Hours_per_Day, dtype: float64

# %% [markdown]
# ### FINAL EDA SUMMARY

# %%
print("=" * 60)
print("STUDENT DROPOUT PREDICTION - EDA SUMMARY")
print("=" * 60)

print("\nDataset Information")
print("-" * 60)
print("Number of Students:", df.shape[0])
print("Number of Features:", df.shape[1])

print("\nDropout Distribution")
print("-" * 60)
print(df["Dropout"].value_counts())

print("\nMissing Values")
print("-" * 60)
print("Total Missing Values:", df.isnull().sum().sum())

print("\nDuplicate Records")
print("-" * 60)
print("Duplicate Rows:", df.duplicated().sum())

print("\nAverage Academic Performance")
print("-" * 60)
print("Average GPA:", round(df["GPA"].mean(), 2))
print("Average Semester GPA:", round(df["Semester_GPA"].mean(), 2))
print("Average CGPA:", round(df["CGPA"].mean(), 2))

print("\nAverage Student Behavior")
print("-" * 60)
print("Average Attendance:", round(df["Attendance_Rate"].mean(), 2))
print("Average Study Hours:", round(df["Study_Hours_per_Day"].mean(), 2))
print("Average Stress Index:", round(df["Stress_Index"].mean(), 2))

print("\nEDA Completed Successfully!")
# Out:
# ...
# STUDENT DROPOUT PREDICTION - EDA SUMMARY
# ...
#
# Dataset Information
# ------------------------------------------------------------
# Number of Students: 10000
# Number of Features: 19
#
# Dropout Distribution
# ------------------------------------------------------------
# Dropout
# 0    7646
# 1    2354
# Name: count, dtype: int64
#
# Missing Values
# ------------------------------------------------------------
# Total Missing Values: 2011
#
# Duplicate Records
# ------------------------------------------------------------
# Duplicate Rows: 0
#
# Average Academic Performance
# ------------------------------------------------------------
# Average GPA: 2.31
# Average Semester GPA: 2.3
# Average CGPA: 2.3
#
# Average Student Behavior
# ------------------------------------------------------------
# Average Attendance: 81.74
# Average Study Hours: 4.01
# Average Stress Index: 5.51
#
# EDA Completed Successfully!

# %% [markdown]
# ### Conclusion
# In this laboratory, Exploratory Data Analysis (EDA) was performed on the Student Dropout Prediction dataset.
#
# Various visualization techniques were used, including histograms, bar charts, scatter plots, and box plots. Histograms were used to understand the distribution of numerical variables such as age, GPA, study hours, attendance, and stress. Bar charts were used to analyze categorical variables such as gender, scholarship, internet access, part-time employment, and dropout status.
#
# Scatter plots were used to investigate relationships between important academic and behavioral factors, including attendance, GPA, study hours, stress, and assignment delays. Box plots were used to examine data distributions and identify potential outliers.
#
# A correlation matrix and heatmap were also created to analyze relationships among numerical features. The IQR method was applied to identify potential outliers.
#
# Overall, the EDA provides important insights into the factors associated with student academic performance and dropout behavior. These findings can be used as a foundation for future data mining and machine learning tasks such as student dropout classification and prediction.
