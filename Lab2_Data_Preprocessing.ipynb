# %% [markdown]
# # Lab 2: Data Preprocessing and Exploration
#
# **Name:** Amit Bhowmik
# **Department:** Computer Science and Engineering
# **ID:** 232031017
# **University:** Feni University
#
# ### Objectives
# - Loading datasets
# - Handling missing values
# - Removing duplicates
# - Encoding categorical variables
# - Feature scaling using normalization and standardization
# - Descriptive statistics

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

import warnings
warnings.filterwarnings("ignore")

# %%
path = "data/student_dropout.csv"
df = pd.read_csv(path)

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#    Student_ID   Age  Gender  Family_Income Internet_Access  \
# 0           1  22.1    Male        25000.0             Yes
# 1           2  20.7    Male        25000.0             Yes
# 2           3  22.4    Male        40183.0             Yes
# 3           4  24.4    Male            NaN             Yes
# 4           5  20.5  Female        25319.0             Yes
#
#    Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 0                 3.36             86.1                      2
# 1                 4.30             68.0                      2
# 2                 4.40             70.9                      0
# 3                  NaN             82.2                      2
# 4                 4.19             75.7                      1
#
#    Travel_Time_Minutes Part_Time_Job Scholarship  Stress_Index   GPA  \
# 0                 20.4           Yes          No           5.5  0.96
# 1                 44.0            No          No           6.8  1.28
# 2                 48.9           Yes          No           5.5  1.68
# 3                 38.6            No          No           NaN  1.78
# 4                 23.0            No          No           7.0  1.48
#
#    Semester_GPA  CGPA Semester   Department Parental_Education  Dropout
# 0          0.90  0.90   Year 1         Arts        High School        0
# 1          1.20  1.19   Year 3  Engineering           Bachelor        1
# 2          1.32  1.32   Year 1         Arts             Master        0
# 3          1.77  1.77   Year 1           CS        High School        1
# 4          0.91  0.87   Year 4     Business           Bachelor        0

# %%
df.tail()
# Out:
#       Student_ID   Age  Gender  Family_Income Internet_Access  \
# 9995        9996  23.9  Female        42286.0              No
# 9996        9997  17.0  Female        61103.0             Yes
# 9997        9998  19.4    Male        25000.0             Yes
# 9998        9999  22.1  Female        40302.0             Yes
# 9999       10000  22.4  Female        76796.0             Yes
#
#       Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 9995                 4.62             92.0                      0
# 9996                 2.87             75.2                      3
# 9997                 4.73             74.9                      4
# 9998                 5.85             74.2                      1
# 9999                 4.95             83.7                      1
#
#       Travel_Time_Minutes Part_Time_Job Scholarship  Stress_Index   GPA  \
# 9995                 10.0           Yes         Yes           5.5  1.60
# 9996                 32.4            No         Yes           6.7  3.09
# 9997                 25.4            No          No           3.5  3.45
# 9998                  5.0            No         Yes           6.2  3.35
# 9999                 15.5           Yes          No           7.9  2.17
#
#       Semester_GPA  CGPA Semester Department Parental_Education  Dropout
# 9995          0.99  0.97   Year 2       Arts           Bachelor        0
# 9996          3.09  3.09   Year 1   Business             Master        1
# 9997          3.37  3.43   Year 4   Business           Bachelor        0
# 9998          3.34  3.34   Year 1         CS        High School        0
# 9999          2.20  2.20   Year 1       Arts             Master        0

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 10000
# Number of Columns: 19

# %%
print("Dataset Columns:\n")
for i, column in enumerate(df.columns, start=1):
    print(i, "-", column)
# Out:
# Dataset Columns:
#
# 1 - Student_ID
# 2 - Age
# 3 - Gender
# 4 - Family_Income
# 5 - Internet_Access
# 6 - Study_Hours_per_Day
# 7 - Attendance_Rate
# 8 - Assignment_Delay_Days
# 9 - Travel_Time_Minutes
# 10 - Part_Time_Job
# 11 - Scholarship
# 12 - Stress_Index
# 13 - GPA
# 14 - Semester_GPA
# 15 - CGPA
# 16 - Semester
# 17 - Department
# 18 - Parental_Education
# 19 - Dropout

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             10000 non-null  int64
#  1   Age                    10000 non-null  float64
#  2   Gender                 10000 non-null  str
#  3   Family_Income          9500 non-null   float64
#  4   Internet_Access        10000 non-null  str
#  5   Study_Hours_per_Day    9500 non-null   float64
#  6   Attendance_Rate        10000 non-null  float64
#  7   Assignment_Delay_Days  10000 non-null  int64
#  8   Travel_Time_Minutes    10000 non-null  float64
#  9   Part_Time_Job          10000 non-null  str
#  10  Scholarship            10000 non-null  str
#  11  Stress_Index           9500 non-null   float64
#  12  GPA                    10000 non-null  float64
#  13  Semester_GPA           10000 non-null  float64
#  14  CGPA                   10000 non-null  float64
#  15  Semester               10000 non-null  str
#  16  Department             10000 non-null  str
#  17  Parental_Education     9489 non-null   str
#  18  Dropout                10000 non-null  int64
# dtypes: float64(9), int64(3), str(7)
# memory usage: 1.4 MB

# %%
missing_values = df.isnull().sum()
print(missing_values)
print("\nTotal Missing Values:", df.isnull().sum().sum())
# Out:
# Student_ID                 0
# Age                        0
# Gender                     0
# Family_Income            500
# Internet_Access            0
# Study_Hours_per_Day      500
# Attendance_Rate            0
# Assignment_Delay_Days      0
# Travel_Time_Minutes        0
# Part_Time_Job              0
# Scholarship                0
# Stress_Index             500
# GPA                        0
# Semester_GPA               0
# CGPA                       0
# Semester                   0
# Department                 0
# Parental_Education       511
# Dropout                    0
# dtype: int64
#
# Total Missing Values: 2011

# %%
# Handle missing values
missing_before = df.isnull().sum().sum()
print("Missing values before handling:", missing_before)

numeric_columns = df.select_dtypes(include=np.number).columns
for column in numeric_columns:
    df[column] = df[column].fillna(df[column].median())

categorical_columns = df.select_dtypes(exclude=np.number).columns
for column in categorical_columns:
    if df[column].isnull().sum() > 0:
        df[column] = df[column].fillna(df[column].mode()[0])

missing_after = df.isnull().sum().sum()
print("Missing values after handling:", missing_after)
# Out:
# Missing values before handling: 2011
# Missing values after handling: 0

# %%
duplicate_count = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
df = df.drop_duplicates()
print("Dataset shape after removing duplicates:", df.shape)
# Out:
# Dataset shape after removing duplicates: (10000, 19)

# %%
df.describe()
# Out:
#         Student_ID          Age  Family_Income  Study_Hours_per_Day  \
# count  10000.00000  10000.00000   10000.000000         10000.000000
# mean    5000.50000     21.02606   37945.410100             4.013862
# std     2886.89568      2.13981   20065.697032             1.262649
# min        1.00000     17.00000   25000.000000             0.500000
# 25%     2500.75000     19.50000   25000.000000             3.210000
# 50%     5000.50000     21.00000   29740.500000             4.000000
# 75%     7500.25000     22.50000   43361.750000             4.810000
# max    10000.00000     29.60000  316601.000000             8.980000
#
#        Attendance_Rate  Assignment_Delay_Days  Travel_Time_Minutes  \
# count      10000.00000           10000.000000          10000.00000
# mean          81.73683               1.799700             30.17926
# std            8.22093               1.344307             11.91887
# min           38.20000               0.000000              5.00000
# 25%           76.40000               1.000000             21.90000
# 50%           81.80000               2.000000             30.20000
# 75%           87.30000               3.000000             38.40000
# max          100.00000               8.000000             74.90000
#
#        Stress_Index           GPA  Semester_GPA          CGPA      Dropout
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.00000
# mean       5.506790      2.308440      2.300057      2.298761      0.23540
# std        1.721232      1.061717      1.074407      1.072555      0.42427
# min        1.000000      0.000000      0.000000      0.000000      0.00000
# 25%        4.400000      1.550000      1.520000      1.520000      0.00000
# 50%        5.500000      2.350000      2.350000      2.350000      0.00000
# 75%        6.600000      3.120000      3.150000      3.150000      0.00000
# max       10.000000      4.000000      4.000000      4.000000      1.00000

# %%
categorical_columns = df.select_dtypes(exclude=np.number).columns
print("Categorical Columns:")
print(categorical_columns.tolist())
# Out:
# Categorical Columns:
# ['Gender', 'Internet_Access', 'Part_Time_Job', 'Scholarship', 'Semester', 'Department', 'Parental_Education']

# %%
# Encode the categorical target
print("Dropout values before encoding:")
print(df["Dropout"].unique())
# Out:
# Dropout values before encoding:
# [0 1]

# %%
label_encoder = LabelEncoder()

df["Dropout_Encoded"] = label_encoder.fit_transform(df["Dropout"])

print("Dropout values after encoding:")
print(df[["Dropout", "Dropout_Encoded"]].head())
# Out:
# Dropout values after encoding:
#    Dropout  Dropout_Encoded
# 0        0                0
# 1        1                1
# 2        0                0
# 3        1                1
# 4        0                0

# %%
print("Encoding Mapping:")
for number, category in enumerate(label_encoder.classes_):
    print(category, "=", number)
# Out:
# Encoding Mapping:
# 0 = 0
# 1 = 1

# %%
# Normalization
numeric_columns = df.select_dtypes(include=np.number).columns

minmax_scaler = MinMaxScaler()
normalized_data = minmax_scaler.fit_transform(df[numeric_columns])

normalized_df = pd.DataFrame(normalized_data, columns=numeric_columns)
normalized_df.head()
# Out:
#    Student_ID       Age  Family_Income  Study_Hours_per_Day  Attendance_Rate  \
# 0      0.0000  0.404762       0.000000             0.337264         0.775081
# 1      0.0001  0.293651       0.000000             0.448113         0.482201
# 2      0.0002  0.428571       0.052068             0.459906         0.529126
# 3      0.0003  0.587302       0.016257             0.412736         0.711974
# 4      0.0004  0.277778       0.001094             0.435142         0.606796
#
#    Assignment_Delay_Days  Travel_Time_Minutes  Stress_Index    GPA  \
# 0                  0.250             0.220315      0.500000  0.240
# 1                  0.250             0.557940      0.644444  0.320
# 2                  0.000             0.628040      0.500000  0.420
# 3                  0.250             0.480687      0.500000  0.445
# 4                  0.125             0.257511      0.666667  0.370
#
#    Semester_GPA    CGPA  Dropout  Dropout_Encoded
# 0        0.2250  0.2250      0.0              0.0
# 1        0.3000  0.2975      1.0              1.0
# 2        0.3300  0.3300      0.0              0.0
# 3        0.4425  0.4425      1.0              1.0
# 4        0.2275  0.2175      0.0              0.0

# %%
print("Minimum values:")
print(normalized_df.min().head())

print("\nMaximum values:")
print(normalized_df.max().head())
# Out:
# Minimum values:
# Student_ID             0.0
# Age                    0.0
# Family_Income          0.0
# Study_Hours_per_Day    0.0
# Attendance_Rate        0.0
# dtype: float64
#
# Maximum values:
# Student_ID             1.0
# Age                    1.0
# Family_Income          1.0
# Study_Hours_per_Day    1.0
# Attendance_Rate        1.0
# dtype: float64

# %%
# Standardization
standard_scaler = StandardScaler()
standardized_data = standard_scaler.fit_transform(df[numeric_columns])

standardized_df = pd.DataFrame(standardized_data, columns=numeric_columns)
standardized_df.head()
# Out:
#    Student_ID       Age  Family_Income  Study_Hours_per_Day  Attendance_Rate  \
# 0   -1.731878  0.501911      -0.645184            -0.517875         0.530766
# 1   -1.731531 -0.152386      -0.645184             0.226629        -1.671042
# 2   -1.731185  0.642117       0.111519             0.305831        -1.318266
# 3   -1.730838  1.576826      -0.408923            -0.010979         0.056343
# 4   -1.730492 -0.245857      -0.629285             0.139506        -0.734361
#
#    Assignment_Delay_Days  Travel_Time_Minutes  Stress_Index       GPA  \
# 0               0.149006            -0.820527     -0.003945 -1.270120
# 1               0.149006             1.159626      0.751366 -0.968706
# 2              -1.338824             1.570759     -0.003945 -0.591939
# 3               0.149006             0.706540     -0.003945 -0.497747
# 4              -0.594909            -0.602374      0.867567 -0.780323
#
#    Semester_GPA      CGPA   Dropout  Dropout_Encoded
# 0     -1.303163 -1.304205 -0.554863        -0.554863
# 1     -1.023925 -1.033809  1.802245         1.802245
# 2     -0.912230 -0.912597 -0.554863        -0.554863
# 3     -0.493373 -0.493017  1.802245         1.802245
# 4     -1.293855 -1.332177 -0.554863        -0.554863

# %%
print("Mean of standardized data:")
print(standardized_df.mean().head())

print("\nStandard deviation:")
print(standardized_df.std().head())
# Out:
# Mean of standardized data:
# Student_ID             0.000000e+00
# Age                    1.158185e-15
# Family_Income         -6.821210e-17
# Study_Hours_per_Day    3.145928e-16
# Attendance_Rate        2.872369e-16
# dtype: float64
#
# Standard deviation:
# Student_ID             1.00005
# Age                    1.00005
# Family_Income          1.00005
# Study_Hours_per_Day    1.00005
# Attendance_Rate        1.00005
# dtype: float64

# %%
output_path = "data/processed_dataset.csv"
df.to_csv(output_path, index=False)
print("Processed dataset saved successfully!")
# Out:
# Processed dataset saved successfully!

# %% [markdown]
# ## Conclusion
#
# The dataset was loaded, examined, cleaned, encoded, scaled, and summarized. Missing values and duplicate records were investigated, the target variable was encoded, and both Min-Max normalization and standardization were demonstrated. The processed dataset was saved for future data mining tasks.
